# %%
# !pip install -U "langgraph-cli[inmem]"

# Install debugpy package
# !pip install debugpy
# Out:
# ...
#   Using cached cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached protobuf-6.33.5-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.8/529.8 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 29.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 3.3 MB/s eta 0:00:00a 0:00:01m
# ...
# Using cached protobuf-6.33.5-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# ...

# %%
# !langgraph new "/Users/leimao/Documents/study-code/ai-engineer-training/week04/app" --template new-langgraph-project-python
# Out:
# 📥 Attempting to download repository as a ZIP archive...
# URL: https://github.com/langchain-ai/new-langgraph-project/archive/refs/heads/main.zip
# ✅ Downloaded and extracted repository to /Users/leimao/Documents/study-code/ai-engineer-training/week04/D:\AI工程化训练营\workspace\week04\app
# 🎉 New project created at /Users/leimao/Documents/study-code/ai-engineer-training/week04/D:\AI工程化训练营\workspace\week04\app

# %%
# !cd app && langgraph dev
# Out:
# INFO:langgraph_api.cli:
#
#         Welcome to
#
# ╦  ┌─┐┌┐┌┌─┐╔═╗┬─┐┌─┐┌─┐┬ ┬
# ║  ├─┤││││ ┬║ ╦├┬┘├─┤├─┘├─┤
# ╩═╝┴ ┴┘└┘└─┘╚═╝┴└─┴ ┴┴  ┴ ┴
#
# - 🚀 API: http://127.0.0.1:2024
# - 🎨 Studio UI: https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024
# - 📚 API Docs: http://127.0.0.1:2024/docs
#
# This in-memory server is designed for development and testing.
# For production use, please use LangSmith Deployment.
#
#
# Process SpawnProcess-1:
# Traceback (most recent call last):
#   File "/Users/leimao/miniconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Users/leimao/miniconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leimao/miniconda3/lib/python3.13/site-packages/uvicorn/_subprocess.py", line 80, in subprocess_started
#     target(sockets=sockets)
#     ~~~~~~^^^^^^^^^^^^^^^^^
# ...

# %%
# !cd app2 && langgraph dev
