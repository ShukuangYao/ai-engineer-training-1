# %%
from dotenv import load_dotenv
load_dotenv()

# %%
# !pip install llama-index-readers-smart-pdf-loader
# !pip install llmsherpa
# Out:
# Requirement already satisfied: llama-index-readers-smart-pdf-loader in /Users/leimao/miniconda3/lib/python3.13/site-packages (0.4.1)
# Requirement already satisfied: llama-index-core<0.15,>=0.13.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-readers-smart-pdf-loader) (0.14.13)
# Requirement already satisfied: llmsherpa<0.2,>=0.1.4 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-readers-smart-pdf-loader) (0.1.4)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (3.13.2)
# Requirement already satisfied: aiosqlite in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (0.22.1)
# Requirement already satisfied: banks<3,>=2.2.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (2.3.0)
# Requirement already satisfied: dataclasses-json in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (2025.12.0)
# Requirement already satisfied: httpx in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (0.28.1)
# Requirement already satisfied: llama-index-workflows!=2.9.0,<3,>=2 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (2.13.1)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (3.6.1)
# Requirement already satisfied: nltk>3.8.1 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (3.9.2)
# Requirement already satisfied: numpy in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (2.4.0)
# Requirement already satisfied: pillow>=9.0.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (12.0.0)
# Requirement already satisfied: platformdirs in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (4.3.7)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (2.11.7)
# Requirement already satisfied: pyyaml>=6.0.1 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (6.0.3)
# Requirement already satisfied: requests>=2.31.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (2.32.5)
# Requirement already satisfied: setuptools>=80.9.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (80.10.2)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (2.0.45)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (9.1.2)
# Requirement already satisfied: tiktoken>=0.7.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (0.12.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (0.9.0)
# Requirement already satisfied: wrapt in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (1.17.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (1.22.0)
# Requirement already satisfied: griffe in /Users/leimao/miniconda3/lib/python3.13/site-packages (from banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (1.15.0)
# Requirement already satisfied: jinja2 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (3.1.6)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llama-index-workflows!=2.9.0,<3,>=2->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (0.4.2)
# Requirement already satisfied: urllib3 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llmsherpa<0.2,>=0.1.4->llama-index-readers-smart-pdf-loader) (2.5.0)
# Requirement already satisfied: idna>=2.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from yarl<2.0,>=1.17.0->aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (3.7)
# Requirement already satisfied: click in /Users/leimao/miniconda3/lib/python3.13/site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (8.2.1)
# Requirement already satisfied: joblib in /Users/leimao/miniconda3/lib/python3.13/site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (2025.11.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (0.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (3.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (3.26.1)
# Requirement already satisfied: packaging>=17.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (25.0)
# Requirement already satisfied: colorama>=0.4 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from griffe->banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (0.4.6)
# Requirement already satisfied: anyio in /Users/leimao/miniconda3/lib/python3.13/site-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (4.12.0)
# Requirement already satisfied: httpcore==1.* in /Users/leimao/miniconda3/lib/python3.13/site-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from jinja2->banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-smart-pdf-loader) (3.0.3)
# Requirement already satisfied: llmsherpa in /Users/leimao/miniconda3/lib/python3.13/site-packages (0.1.4)
# Requirement already satisfied: urllib3 in /Users/leimao/miniconda3/lib/python3.13/site-packages (from llmsherpa) (2.5.0)

# %%
from llama_index.readers.smart_pdf_loader import SmartPDFLoader

llmsherpa_api_url = "https://readers.llmsherpa.com/api/document/developer/parseDocument?renderFormat=all"
pdf_url = "https://arxiv.org/pdf/1910.13461.pdf"  # also allowed is a file path e.g. /home/downloads/xyz.pdf
documents = SmartPDFLoader(llmsherpa_api_url=llmsherpa_api_url).load_data(pdf_url)


# 参考  https://github.com/run-llama/llama_index/tree/main/llama-index-integrations/readers/llama-index-readers-smart-pdf-loader/llama_index


# base.py

"""Smart PDF Loader."""

from typing import Any, Dict, List, Optional

from llama_index.core.readers.base import BaseReader
from llama_index.core.schema import Document


class SmartPDFLoader(BaseReader):
    """
    SmartPDFLoader uses nested layout information such as sections, paragraphs, lists and tables to smartly chunk PDFs for optimal usage of LLM context window.

    Args:
        llmsherpa_api_url (str): Address of the service hosting llmsherpa PDF parser

    """

    def __init__(
        self, *args: Any, llmsherpa_api_url: str = None, **kwargs: Any
    ) -> None:
        super().__init__(*args, **kwargs)
        from llmsherpa.readers import LayoutPDFReader

        self.pdf_reader = LayoutPDFReader(llmsherpa_api_url)

    def load_data(
        self, pdf_path_or_url: str, extra_info: Optional[Dict] = None
    ) -> List[Document]:
        """
        Load data and extract table from PDF file.

        Args:
            pdf_path_or_url (str): A url or file path pointing to the PDF

        Returns:
            List[Document]: List of documents.

        """
        results = []
        doc = self.pdf_reader.read_pdf(str(pdf_path_or_url))
        for chunk in doc.chunks():
            document = Document(
                text=chunk.to_context_text(),
                extra_info={**extra_info, "chunk_type": chunk.tag}
                if extra_info
                else {"chunk_type": chunk.tag},
            )
            results.append(document)
        return results
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/Documents/study-code/ai-engineer-training/week03/.venv/lib/python3.11/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File ~/Documents/study-code/ai-engineer-training/week03/.venv/lib/python3.11/site-packages/urllib3/util/connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# File ~/.local/share/uv/python/cpython-3.11.14-macos-x86_64-none/lib/python3.11/socket.py:974, in getaddrinfo(host, port, family, type, proto, flags)
#     973 addrlist = []
# --> 974 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     975     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# The above exception was the direct cause of the following exception:
#
# NameResolutionError                       Traceback (most recent call last)
# File ~/Documents/study-code/ai-engineer-training/week03/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/Documents/study-code/ai-engineer-training/week03/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:488, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488     raise new_e
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File ~/Documents/study-code/ai-engineer-training/week03/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~/Documents/study-code/ai-engineer-training/week03/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~/Documents/study-code/ai-engineer-training/week03/.venv/lib/python3.11/site-packages/urllib3/connection.py:753, in HTTPSConnection.connect(self)
#     752 sock: socket.socket | ssl.SSLSocket
# --> 753 self.sock = sock = self._new_conn()
#     754 server_hostname: str = self.host
#
# File ~/Documents/study-code/ai-engineer-training/week03/.venv/lib/python3.11/site-packages/urllib3/connection.py:205, in HTTPConnection._new_conn(self)
#     204 except socket.gaierror as e:
# --> 205     raise NameResolutionError(self.host, self, e) from e
#     206 except SocketTimeout as e:
#
# NameResolutionError: <urllib3.connection.HTTPSConnection object at 0x114a3a5d0>: Failed to resolve 'readers.llmsherpa.com' ([Errno 8] nodename nor servname provided, or not known)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# Cell In[2], line 5
#       3 llmsherpa_api_url = "https://readers.llmsherpa.com/api/document/developer/parseDocument?renderFormat=all"
#       4 pdf_url = "https://arxiv.org/pdf/1910.13461.pdf"  # also allowed is a file path e.g. /home/downloads/xyz.pdf
# ----> 5 documents = SmartPDFLoader(llmsherpa_api_url=llmsherpa_api_url).load_data(pdf_url)
#       8 # 参考  https://github.com/run-llama/llama_index/tree/main/llama-index-integrations/readers/llama-index-readers-smart-pdf-loader/llama_index
#       9
#      10
#      11 # base.py
#      13 """Smart PDF Loader."""
#
# File ~/Documents/study-code/ai-engineer-training/week03/.venv/lib/python3.11/site-packages/llama_index/readers/smart_pdf_loader/base.py:40, in SmartPDFLoader.load_data(self, pdf_path_or_url, extra_info)
#      29 """
#      30 Load data and extract table from PDF file.
#      31
#    (...)     37
#      38 """
#      39 results = []
# ---> 40 doc = self.pdf_reader.read_pdf(str(pdf_path_or_url))
#      41 for chunk in doc.chunks():
#      42     document = Document(
#      43         text=chunk.to_context_text(),
#      44         extra_info={**extra_info, "chunk_type": chunk.tag}
#      45         if extra_info
#      46         else {"chunk_type": chunk.tag},
#      47     )
#
# File ~/Documents/study-code/ai-engineer-training/week03/.venv/lib/python3.11/site-packages/llmsherpa/readers/file_reader.py:71, in LayoutPDFReader.read_pdf(self, path_or_url, contents)
#      69             file_data = f.read()
#      70             pdf_file = (file_name, file_data, 'application/pdf')
# ---> 71 parser_response = self._parse_pdf(pdf_file)
#      72 response_json = json.loads(parser_response.data.decode("utf-8"))
#      73 blocks = response_json['return_dict']['result']['blocks']
#
# File ~/Documents/study-code/ai-engineer-training/week03/.venv/lib/python3.11/site-packages/llmsherpa/readers/file_reader.py:45, in LayoutPDFReader._parse_pdf(self, pdf_file)
#      43 def _parse_pdf(self, pdf_file):
#      44     auth_header = {}
# ---> 45     parser_response = self.api_connection.request("POST", self.parser_api_url, fields={'file': pdf_file})
#      46     return parser_response
#
# File ~/Documents/study-code/ai-engineer-training/week03/.venv/lib/python3.11/site-packages/urllib3/_request_methods.py:143, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     135     return self.request_encode_url(
#     136         method,
#     137         url,
#    (...)    140         **urlopen_kw,
#     141     )
#     142 else:
# --> 143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File ~/Documents/study-code/ai-engineer-training/week03/.venv/lib/python3.11/site-packages/urllib3/_request_methods.py:278, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     274     extra_kw["headers"].setdefault("Content-Type", content_type)
#     276 extra_kw.update(urlopen_kw)
# --> 278 return self.urlopen(method, url, **extra_kw)
#
# File ~/Documents/study-code/ai-engineer-training/week03/.venv/lib/python3.11/site-packages/urllib3/poolmanager.py:459, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     457     response = conn.urlopen(method, url, **kw)
#     458 else:
# --> 459     response = conn.urlopen(method, u.request_uri, **kw)
#     461 redirect_location = redirect and response.get_redirect_location()
#     462 if not redirect_location:
#
# File ~/Documents/study-code/ai-engineer-training/week03/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:871, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     866 if not conn:
#     867     # Try again
#     868     log.warning(
#     869         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     870     )
# --> 871     return self.urlopen(
#     872         method,
#     873         url,
#     874         body,
#     875         headers,
#     876         retries,
#     877         redirect,
#     878         assert_same_host,
#     879         timeout=timeout,
#     880         pool_timeout=pool_timeout,
#     881         release_conn=release_conn,
#     882         chunked=chunked,
#     883         body_pos=body_pos,
#     884         preload_content=preload_content,
#     885         decode_content=decode_content,
#     886         **response_kw,
#     887     )
#     889 # Handle redirect?
#     890 redirect_location = redirect and response.get_redirect_location()
#
# File ~/Documents/study-code/ai-engineer-training/week03/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:871, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     866 if not conn:
#     867     # Try again
#     868     log.warning(
#     869         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     870     )
# --> 871     return self.urlopen(
#     872         method,
#     873         url,
#     874         body,
#     875         headers,
#     876         retries,
#     877         redirect,
#     878         assert_same_host,
#     879         timeout=timeout,
#     880         pool_timeout=pool_timeout,
#     881         release_conn=release_conn,
#     882         chunked=chunked,
#     883         body_pos=body_pos,
#     884         preload_content=preload_content,
#     885         decode_content=decode_content,
#     886         **response_kw,
#     887     )
#     889 # Handle redirect?
#     890 redirect_location = redirect and response.get_redirect_location()
#
# File ~/Documents/study-code/ai-engineer-training/week03/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:871, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     866 if not conn:
#     867     # Try again
#     868     log.warning(
#     869         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     870     )
# --> 871     return self.urlopen(
#     872         method,
#     873         url,
#     874         body,
#     875         headers,
#     876         retries,
#     877         redirect,
#     878         assert_same_host,
#     879         timeout=timeout,
#     880         pool_timeout=pool_timeout,
#     881         release_conn=release_conn,
#     882         chunked=chunked,
#     883         body_pos=body_pos,
#     884         preload_content=preload_content,
#     885         decode_content=decode_content,
#     886         **response_kw,
#     887     )
#     889 # Handle redirect?
#     890 redirect_location = redirect and response.get_redirect_location()
#
# File ~/Documents/study-code/ai-engineer-training/week03/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     838 elif isinstance(new_e, (OSError, HTTPException)):
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#     846 # Keep track of the error for the retry warning.
#
# File ~/Documents/study-code/ai-engineer-training/week03/.venv/lib/python3.11/site-packages/urllib3/util/retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     517 if new_retry.is_exhausted():
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#     523 return new_retry
#
# MaxRetryError: HTTPSConnectionPool(host='readers.llmsherpa.com', port=443): Max retries exceeded with url: /api/document/developer/parseDocument?renderFormat=all (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x114a3a5d0>: Failed to resolve 'readers.llmsherpa.com' ([Errno 8] nodename nor servname provided, or not known)"))
